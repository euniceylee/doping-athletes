# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/eunicelee/Documents/doping-data/dopingfinal.csv')

# %%
df
# Out:
#               firstname          lastname countrycode     country  sex  \
# 0                 Elmar      Lichtenegger         AUT     Austria    M
# 1               Susanne            Pumper         AUT     Austria    F
# 2                Chaltu              Beji         AZE  Azerbaijan    F
# 3               Dzmitry           Marshin         AZE  Azerbaijan    M
# 4             Tsehynesh             Tsale         AZE  Azerbaijan    F
# 5                Momhed           Khalifa         BHR     Bahrain    M
# 6           SALEM Marwa             Salah         BRN     Bahrain    F
# 7              Natallia           Kareiva         BLR     Belarus    F
# 8                 Pavel         Kryvitski         BLR     Belarus    M
# 9                Andrei        Mikhnevich         BLR     Belarus    M
# 10              Nadzeya         Ostapchuk         BLR     Belarus    F
# 11                Volha           Rezkaya         BLR     Belarus    F
# ...

# %%
df.dtypes
# Out:
# firstname            object
# lastname             object
# countrycode          object
# country              object
# sex                  object
# type                 object
# rule                 object
# infractiondate       object
# ineligibleyears     float64
# sanction             object
# ineligabletodate     object
# Unnamed: 11         float64
# Unnamed: 12         float64
# Unnamed: 13         float64
# Unnamed: 14         float64
# Unnamed: 15         float64
# Unnamed: 16         float64
# Unnamed: 17         float64
# Unnamed: 18         float64
# Unnamed: 19         float64
# Unnamed: 20         float64
# Unnamed: 21         float64
# Unnamed: 22         float64
# Unnamed: 23         float64
# Unnamed: 24         float64
# Unnamed: 25         float64
# Unnamed: 26         float64
# dtype: object

# %%
df.columns
# Out:
# Index([u'firstname', u'lastname', u'countrycode', u'country', u'sex', u'type',
#        u'rule', u'infractiondate', u'ineligibleyears', u'sanction',
#        u'ineligabletodate', u'Unnamed: 11', u'Unnamed: 12', u'Unnamed: 13',
#        u'Unnamed: 14', u'Unnamed: 15', u'Unnamed: 16', u'Unnamed: 17',
#        u'Unnamed: 18', u'Unnamed: 19', u'Unnamed: 20', u'Unnamed: 21',
#        u'Unnamed: 22', u'Unnamed: 23', u'Unnamed: 24', u'Unnamed: 25',
#        u'Unnamed: 26'],
#       dtype='object')

# %%
df['ineligabletodate']
# Out:
# 0      Lifetime ban
# 1          03/05/20
# 2          06/26/19
# 3          06/28/19
# 4          02/10/16
# 5          05/11/17
# 6          12/01/15
# 7          08/21/16
# 8          06/10/19
# 9      Lifetime ban
# 10         08/14/16
# 11         11/01/15
# 12     Lifetime ban
# 13         08/28/16
# 14         07/07/16
# 15         06/02/16
# 16         10/13/16
# 17         02/23/16
# 18         02/02/16
# 19         09/24/16
# 20         10/04/18
# 21         08/23/16
# 22     Lifetime ban
# 23     Lifetime ban
# 24         11/02/15
# 25         11/16/15
# 26         12/24/15
# 27     Lifetime ban
# 28     Lifetime ban
# 29         02/11/17
#            ...
# 969             NaN
# 970             NaN
# 971             NaN
# 972             NaN
# 973             NaN
# 974             NaN
# 975             NaN
# 976             NaN
# 977             NaN
# 978             NaN
# 979             NaN
# 980             NaN
# 981             NaN
# 982             NaN
# ...

# %%
df = pd.read_csv('/Users/eunicelee/Documents/doping-data/dopingfinal.csv')

# %%
df
# Out:
#               firstname          lastname countrycode     country  sex  \
# 0                 Elmar      Lichtenegger         AUT     Austria    M
# 1               Susanne            Pumper         AUT     Austria    F
# 2                Chaltu              Beji         AZE  Azerbaijan    F
# 3               Dzmitry           Marshin         AZE  Azerbaijan    M
# 4             Tsehynesh             Tsale         AZE  Azerbaijan    F
# 5                Momhed           Khalifa         BHR     Bahrain    M
# 6           SALEM Marwa             Salah         BRN     Bahrain    F
# 7              Natallia           Kareiva         BLR     Belarus    F
# 8                 Pavel         Kryvitski         BLR     Belarus    M
# 9                Andrei        Mikhnevich         BLR     Belarus    M
# 10              Nadzeya         Ostapchuk         BLR     Belarus    F
# 11                Volha           Rezkaya         BLR     Belarus    F
# ...

# %%
df['ineligabletodate']
# Out:
# 0      Lifetime ban
# 1          03/05/20
# 2          06/26/19
# 3          06/28/19
# 4          02/10/16
# 5          05/11/17
# 6          12/01/15
# 7          08/21/16
# 8          06/10/19
# 9      Lifetime ban
# 10         08/14/16
# 11         11/01/15
# 12     Lifetime ban
# 13         08/28/16
# 14         07/07/16
# 15         06/02/16
# 16         10/13/16
# 17         02/23/16
# 18         02/02/16
# 19         09/24/16
# 20         10/04/18
# 21         08/23/16
# 22     Lifetime ban
# 23     Lifetime ban
# 24         11/02/15
# 25         11/16/15
# 26         12/24/15
# 27     Lifetime ban
# 28     Lifetime ban
# 29         02/11/17
#            ...
# 969             NaN
# 970             NaN
# 971             NaN
# 972             NaN
# 973             NaN
# 974             NaN
# 975             NaN
# 976             NaN
# 977             NaN
# 978             NaN
# 979             NaN
# 980             NaN
# 981             NaN
# 982             NaN
# ...

# %%
df['ineligabletodate'] = np.where(df['ineligabletodate'] == 'Lifetime ban',np.nan, df['ineligabletodate'])

# %%
df['ineligabletodate'] = pd.to_datetime(df['ineligabletodate'], format = "%m/%d/%y")

# %%
df['ineligabletodate']
# Out:
# 0            NaT
# 1     2020-03-05
# 2     2019-06-26
# 3     2019-06-28
# 4     2016-02-10
# 5     2017-05-11
# 6     2015-12-01
# 7     2016-08-21
# 8     2019-06-10
# 9            NaT
# 10    2016-08-14
# 11    2015-11-01
# 12           NaT
# 13    2016-08-28
# 14    2016-07-07
# 15    2016-06-02
# 16    2016-10-13
# 17    2016-02-23
# 18    2016-02-02
# 19    2016-09-24
# 20    2018-10-04
# 21    2016-08-23
# 22           NaT
# 23           NaT
# 24    2015-11-02
# 25    2015-11-16
# 26    2015-12-24
# 27           NaT
# 28           NaT
# 29    2017-02-11
#          ...
# 969          NaT
# 970          NaT
# 971          NaT
# 972          NaT
# 973          NaT
# 974          NaT
# 975          NaT
# 976          NaT
# 977          NaT
# 978          NaT
# 979          NaT
# 980          NaT
# 981          NaT
# 982          NaT
# 983          NaT
# 984          NaT
# 985          NaT
# 986          NaT
# 987          NaT
# 988          NaT
# 989          NaT
# ...

# %%
df['ineligabletodate']
# Out:
# 0            NaT
# 1     2020-03-05
# 2     2019-06-26
# 3     2019-06-28
# 4     2016-02-10
# 5     2017-05-11
# 6     2015-12-01
# 7     2016-08-21
# 8     2019-06-10
# 9            NaT
# 10    2016-08-14
# 11    2015-11-01
# 12           NaT
# 13    2016-08-28
# 14    2016-07-07
# 15    2016-06-02
# 16    2016-10-13
# 17    2016-02-23
# 18    2016-02-02
# 19    2016-09-24
# 20    2018-10-04
# 21    2016-08-23
# 22           NaT
# 23           NaT
# 24    2015-11-02
# 25    2015-11-16
# 26    2015-12-24
# 27           NaT
# 28           NaT
# 29    2017-02-11
#          ...
# 969          NaT
# 970          NaT
# 971          NaT
# 972          NaT
# 973          NaT
# 974          NaT
# 975          NaT
# 976          NaT
# 977          NaT
# 978          NaT
# 979          NaT
# 980          NaT
# 981          NaT
# 982          NaT
# 983          NaT
# 984          NaT
# 985          NaT
# 986          NaT
# 987          NaT
# 988          NaT
# 989          NaT
# ...

# %%
import datetime as dt

# %%
df['ineligabletodate'].dt.year
# Out:
# 0         NaN
# 1      2020.0
# 2      2019.0
# 3      2019.0
# 4      2016.0
# 5      2017.0
# 6      2015.0
# 7      2016.0
# 8      2019.0
# 9         NaN
# 10     2016.0
# 11     2015.0
# 12        NaN
# 13     2016.0
# 14     2016.0
# 15     2016.0
# 16     2016.0
# 17     2016.0
# 18     2016.0
# 19     2016.0
# 20     2018.0
# 21     2016.0
# 22        NaN
# 23        NaN
# 24     2015.0
# 25     2015.0
# 26     2015.0
# 27        NaN
# 28        NaN
# 29     2017.0
#         ...
# 969       NaN
# 970       NaN
# 971       NaN
# 972       NaN
# 973       NaN
# 974       NaN
# 975       NaN
# 976       NaN
# 977       NaN
# 978       NaN
# 979       NaN
# 980       NaN
# 981       NaN
# 982       NaN
# 983       NaN
# 984       NaN
# 985       NaN
# 986       NaN
# 987       NaN
# 988       NaN
# 989       NaN
# 990       NaN
# 991       NaN
# 992       NaN
# 993       NaN
# 994       NaN
# 995       NaN
# 996       NaN
# 997       NaN
# 998       NaN
# ...

# %%
np.where(df['ineligabletodate'].dt.year < 2016)
# Out:
# (array([  6,  11,  24,  25,  26,  30,  42,  51,  52,  61,  67,  69,  72,
#          73,  90, 122, 148, 179, 231, 233, 245, 248, 249, 250, 251, 252,
#         254, 259, 260, 285]),)

# %%
df1 = df.loc[df['ineligabletodate'].dt.year < 2018]

# %%
df1
# Out:
#               firstname          lastname countrycode         country sex  \
# 4             Tsehynesh             Tsale         AZE      Azerbaijan   F
# 5                Momhed           Khalifa         BHR         Bahrain   M
# 6           SALEM Marwa             Salah         BRN         Bahrain   F
# 7              Natallia           Kareiva         BLR         Belarus   F
# 10              Nadzeya         Ostapchuk         BLR         Belarus   F
# 11                Volha           Rezkaya         BLR         Belarus   F
# 13              Amantle           Montsho         BOT        Botswana   F
# 14                Eilas            Bastos         BRA          Brazil   M
# 15                Jamil   Da Silva Santos         BRA          Brazil   M
# 16         Simone Alves          Da Silva         BRA          Brazil   F
# 17       Guza Reze Reze   De Aquino Silva         BRA          Brazil   F
# 18             Ivanildo         Dos Anjos         BRA          Brazil   M
# ...

# %%
df1.to_csv('/Users/eunicelee/Documents/doping-data/eligible.csv')
